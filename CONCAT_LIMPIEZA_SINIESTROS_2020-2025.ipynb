# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
file = "/Users/radc/Desktop/PARTES_DE_ACCIDENTE_2020_25.xlsx"

xls = pd.ExcelFile(file)

print(xls.sheet_names)
# Out:
# ['2020', '2021', '2022', '2023', '2024', '2025']

# %%
dfs = pd.read_excel(file, sheet_name=None)

# %%
dfs.keys() # Verifico que tengo los nombres de todas las hojas
# Out:
# dict_keys(['2020', '2021', '2022', '2023', '2024', '2025'])

# %%
df = pd.concat(
    [d.assign(sheet=name) for name, d in dfs.items()],
    ignore_index=True
) # Las concateno en un solo DF

# %%
df.head()
# Out:
#          NIF            Nombre  Apellido1 Apellido2 FechaParteAccidente  \
# 0  10550152Y              JUAN  RODRIGUEZ  INCIARTE 2020-01-03 00:00:00
# 1  44625560V           IGNACIO      ARIÑO   GARRIDO 2020-01-03 10:00:00
# 2  70062257W            CARLOS     SELMAN     NEIRA 2020-01-03 11:00:00
# 3  11853175X              JUAN    CABRERO      PICO 2020-01-03 12:00:00
# 4  07516676T  FRANCISCO JAVIER   DE MARCO    MARTIN 2020-01-04 10:30:00
#
#        FechaAltaParte     Codigo  \
# 0 2020-01-04 12:06:00  743808511
# 1 2020-01-08 11:18:00  743809331
# 2 2020-01-04 18:52:00  743808601
# 3 2020-01-07 12:13:00  743808501
# 4 2020-01-07 08:48:00  743808521
#
#                                     DescripcionParte  \
# 0                Caída en pista de esquí en Baqueira
# 1  Resbalón como consecuencia se produce un impac...
# 2  Bajando por Peñalara, sufrí caída con golpe en...
# 3  Caída de esquí de montaña por la que pasadas u...
# 4  Caminando por un sendero ascendente me resbalé...
#
#                      Actividad               Lugar  ... ActividadOrganizada  \
# 0                 Esquí Alpino      Pista en Beret  ...               False
# 1                 Esquí Alpino            Formigal  ...               False
# 2         Carreras por montaña     Puerto de Cotos  ...               False
# 3  Esquí de montaña/Splitboard         Els Pedrons  ...               False
# 4                   Senderismo  Manzanares el Real  ...               False
#
#   Festivo NResponsables TamañoGrupo CentroHospitalizacion  DescripcionGrado  \
# 0   False             1           3                   NaN              Leve
# 1   False             1           1                   NaN              Leve
# 2   False             1           1                   NaN              Leve
# 3   False             1           1                   NaN              Leve
# 4   False             1           0                   NaN              Leve
#
#       Pais  Provincia                     TipoAccidente  sheet
# 0   España     LLEIDA       Deslizamiento por pendiente   2020
# 1   España     HUESCA  Tropiezos (caída al mismo nivel)   2020
# 2   España     MADRID  Tropiezos (caída al mismo nivel)   2020
# 3  Andorra          -       Deslizamiento por pendiente   2020
# 4   España     MADRID       Deslizamiento por pendiente   2020
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3982 entries, 0 to 3981
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NIF                    3982 non-null   str
#  1   Nombre                 3982 non-null   str
#  2   Apellido1              3982 non-null   str
#  3   Apellido2              3981 non-null   str
#  4   FechaParteAccidente    3982 non-null   datetime64[us]
#  5   FechaAltaParte         3982 non-null   datetime64[us]
#  6   Codigo                 3982 non-null   int64
#  7   DescripcionParte       3982 non-null   str
#  8   Actividad              3982 non-null   str
#  9   Lugar                  3860 non-null   str
#  10  FechaRecepcion         3982 non-null   datetime64[us]
#  11  CentroUrgencias        1604 non-null   object
#  12  Helicoptero            2 non-null      object
#  13  MacizoMontañoso        3792 non-null   object
#  14  NombreParaje           3817 non-null   object
#  15  Entrenamiento          3982 non-null   bool
#  16  ActividadPersonal      3982 non-null   bool
#  17  ActividadOrganizada    3982 non-null   bool
#  18  Festivo                3982 non-null   bool
#  19  NResponsables          3982 non-null   int64
#  20  TamañoGrupo            3982 non-null   int64
#  21  CentroHospitalizacion  281 non-null    object
#  22  DescripcionGrado       3830 non-null   str
#  23  Pais                   3982 non-null   str
#  24  Provincia              3982 non-null   str
#  25  TipoAccidente          3982 non-null   str
#  26  sheet                  3982 non-null   str
# dtypes: bool(4), datetime64[us](3), int64(3), object(5), str(12)
# memory usage: 731.2+ KB

# %%
cols_keep = [
    "NIF",
    "FechaParteAccidente",
    "Actividad",
    "Lugar",
    "Provincia",
    "TipoAccidente",
    "DescripcionGrado",
    "TamañoGrupo",
    "NResponsables",
    "Entrenamiento",
    "ActividadPersonal",
    "ActividadOrganizada",
    "Festivo",
    "sheet"
]

df = df[cols_keep] # Las columnas que creo que nos pueden aportar información relevante para el análisis

# %%
df.head()
# Out:
#          NIF FechaParteAccidente                    Actividad  \
# 0  10550152Y 2020-01-03 00:00:00                 Esquí Alpino
# 1  44625560V 2020-01-03 10:00:00                 Esquí Alpino
# 2  70062257W 2020-01-03 11:00:00         Carreras por montaña
# 3  11853175X 2020-01-03 12:00:00  Esquí de montaña/Splitboard
# 4  07516676T 2020-01-04 10:30:00                   Senderismo
#
#                 Lugar Provincia                     TipoAccidente  \
# 0      Pista en Beret    LLEIDA       Deslizamiento por pendiente
# 1            Formigal    HUESCA  Tropiezos (caída al mismo nivel)
# 2     Puerto de Cotos    MADRID  Tropiezos (caída al mismo nivel)
# 3         Els Pedrons         -       Deslizamiento por pendiente
# 4  Manzanares el Real    MADRID       Deslizamiento por pendiente
#
#   DescripcionGrado  TamañoGrupo  NResponsables  Entrenamiento  \
# 0             Leve            3              1          False
# 1             Leve            1              1          False
# 2             Leve            1              1          False
# 3             Leve            1              1          False
# 4             Leve            0              1          False
#
#    ActividadPersonal  ActividadOrganizada  Festivo sheet
# 0              False                False    False  2020
# 1               True                False    False  2020
# 2               True                False    False  2020
# 3               True                False    False  2020
# 4               True                False    False  2020

# %%
df.info() # Nos quedamos con 14 de 26 columnas
# Out:
# <class 'pandas.DataFrame'>
# Index: 3957 entries, 0 to 3981
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NIF                  3957 non-null   str
#  1   FechaParteAccidente  3957 non-null   datetime64[us]
#  2   Actividad            3957 non-null   str
#  3   Lugar                3836 non-null   str
#  4   Provincia            3957 non-null   str
#  5   TipoAccidente        3957 non-null   str
#  6   DescripcionGrado     3805 non-null   str
#  7   TamañoGrupo          3957 non-null   int64
#  8   NResponsables        3957 non-null   int64
#  9   Entrenamiento        3957 non-null   bool
#  10  ActividadPersonal    3957 non-null   bool
#  11  ActividadOrganizada  3957 non-null   bool
#  12  Festivo              3957 non-null   bool
#  13  sheet                3957 non-null   str
# dtypes: bool(4), datetime64[us](1), int64(2), str(7)
# memory usage: 355.5 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
dups = df[df.duplicated(
    subset=[
        "NIF",
        "FechaParteAccidente",
        "Lugar",
        "TipoAccidente"
    ],
    keep=False
)]

dups # Muestra los registros duplicados - los originales y las copias
# Out:
#             NIF FechaParteAccidente  \
# 87    05345381C 2020-02-18 14:00:00
# 88    05345381C 2020-02-18 14:00:00
# 317   04191894Y 2020-08-15 12:00:00
# 318   04191894Y 2020-08-15 12:00:00
# 380   51888566Z 2020-09-22 12:00:00
# 381   51888566Z 2020-09-22 12:00:00
# 1018  06988343T 2021-07-06 15:00:00
# 1019  06988343T 2021-07-06 15:00:00
# 1621  50688629X 2022-04-24 10:00:00
# 1622  50688629X 2022-04-24 10:00:00
# 2214  50676554X 2023-02-20 12:00:00
# 2215  50676554X 2023-02-20 12:00:00
# 2218  15941884D 2023-02-22 16:00:00
# 2219  15941884D 2023-02-22 16:00:00
# 2328  02665694V 2023-04-11 00:00:00
# 2329  02665694V 2023-04-11 00:00:00
# 2455  50636271T 2023-06-14 20:30:00
# 2456  50636271T 2023-06-14 20:30:00
# 2826  02302403B 2024-01-18 20:15:00
# 2827  02302403B 2024-01-18 20:15:00
# 3133  02442123Y 2024-06-25 16:00:00
# 3134  02442123Y 2024-06-25 16:00:00
# 3265  50451124A 2024-09-21 09:00:00
# 3266  50451124A 2024-09-21 09:00:00
# 3276  02282680E 2024-09-27 21:00:00
# 3277  02282680E 2024-09-27 21:00:00
# 3307  06026687C 2024-10-12 10:30:00
# 3308  06026687C 2024-10-12 10:30:00
# 3408  60249595Z 2024-12-15 00:00:00
# 3409  60249595Z 2024-12-15 00:00:00
# 3490  11843025A 2025-02-08 00:00:00
# 3491  11843025A 2025-02-08 00:00:00
# 3534  02652024D 2025-03-02 16:00:00
# 3535  02652024D 2025-03-02 16:00:00
# 3769  06574261X 2025-08-01 10:00:00
# 3770  06574261X 2025-08-01 10:00:00
#
#                                       Actividad  \
# 87                                 Esquí Alpino
# 88                                 Esquí Alpino
# 317                                   Alpinismo
# 318                                   Alpinismo
# 380                                  Senderismo
# 381                                  Senderismo
# 1018  Montañismo/Progresión por terreno abrupto
# 1019  Montañismo/Progresión por terreno abrupto
# 1621                                 Senderismo
# 1622                                 Senderismo
# 2214                               Esquí Alpino
# 2215                               Esquí Alpino
# 2218                               Esquí Alpino
# 2219                               Esquí Alpino
# 2328                                 Senderismo
# 2329                                 Senderismo
# 2455                                  Rocódromo
# 2456                                  Rocódromo
# 2826                                  Rocódromo
# 2827                                  Rocódromo
# 3133                                 Senderismo
# 3134                                 Senderismo
# 3265                       Carreras por montaña
# 3266                       Carreras por montaña
# 3276                       Carreras por montaña
# 3277                       Carreras por montaña
# 3307                      Escalada alta montaña
# 3308                      Escalada alta montaña
# 3408                      Escalada alta montaña
# 3409                      Escalada alta montaña
# 3490                          Escalada en hielo
# 3491                          Escalada en hielo
# 3534                                  Rocódromo
# 3535                                  Rocódromo
# 3769                                 Senderismo
# 3770                                 Senderismo
#
#                                               Lugar   Provincia  \
# 87                                         Cervinia           -
# 88                                         Cervinia           -
# 317       PIC DE SERRE MOURÈNE CIRQUE DE TROUMOUSE.           -
# 318       PIC DE SERRE MOURÈNE CIRQUE DE TROUMOUSE.           -
# 380                                     La Barranca      MADRID
# 381                                     La Barranca      MADRID
# 1018  Cerca del refugio du Clot (Marcadau, Francia)           -
# 1019  Cerca del refugio du Clot (Marcadau, Francia)           -
# 1621                                    Bustarviejo      MADRID
# 1622                                    Bustarviejo      MADRID
# 2214                                Cortina Ampezzo           -
# 2215                                Cortina Ampezzo           -
# 2218                     Final del remonte Sodlisia           -
# 2219                     Final del remonte Sodlisia           -
# 2328                                          Nepal  EXTRANJERO
# 2329                                          Nepal  EXTRANJERO
# 2455                              Sputnik Las Rozas      MADRID
# 2456                              Sputnik Las Rozas      MADRID
# 2826                                         Roc 30      MADRID
# 2827                                         Roc 30      MADRID
# 3133                              Alcalá de Henares      MADRID
# 3134                              Alcalá de Henares      MADRID
# 3265                           Villaviciosa de Odón      MADRID
# 3266                           Villaviciosa de Odón      MADRID
# 3276                                   Torrelodones      MADRID
# 3277                                   Torrelodones      MADRID
# 3307                                      Finestrat    ALICANTE
# 3308                                      Finestrat    ALICANTE
# 3408                                      Zarzalejo      MADRID
# 3409                                      Zarzalejo      MADRID
# 3490                               Cascada de hielo      MADRID
# 3491                               Cascada de hielo           -
# 3534                                            NaN      MADRID
# 3535                                            NaN      MADRID
# 3769                                    El Berrocal       ÁVILA
# 3770                                    El Berrocal       ÁVILA
#
#                          TipoAccidente DescripcionGrado  TamañoGrupo  \
# 87    Tropiezos (caída al mismo nivel)             Leve            2
# 88    Tropiezos (caída al mismo nivel)             Leve            2
# 317                  Caída en vertical           Mortal            5
# 318                  Caída en vertical           Mortal            5
# 380   Tropiezos (caída al mismo nivel)             Leve            1
# 381   Tropiezos (caída al mismo nivel)             Leve            1
# 1018  Tropiezos (caída al mismo nivel)            Grave            9
# 1019  Tropiezos (caída al mismo nivel)            Grave            9
# 1621  Tropiezos (caída al mismo nivel)            Grave            0
# 1622  Tropiezos (caída al mismo nivel)             Leve            0
# 2214  Tropiezos (caída al mismo nivel)             Leve           16
# 2215  Tropiezos (caída al mismo nivel)             Leve           16
# 2218  Tropiezos (caída al mismo nivel)            Grave            0
# 2219  Tropiezos (caída al mismo nivel)            Grave            2
# 2328                 Problemas físicos             Leve            5
# 2329                 Problemas físicos             Leve            5
# 2455             Colisión con personas             Leve           12
# 2456             Colisión con personas             Leve            8
# 2826                 Caída en vertical             Leve            1
# 2827                 Caída en vertical             Leve            1
# 3133                 Problemas físicos              NaN           20
# 3134                 Problemas físicos             Leve           20
# 3265  Tropiezos (caída al mismo nivel)             Leve            0
# 3266  Tropiezos (caída al mismo nivel)             Leve            0
# 3276                 Problemas físicos             Leve            1
# 3277                 Problemas físicos             Leve            1
# 3307                 Caída en vertical            Grave            2
# 3308                 Caída en vertical            Grave            2
# 3408                 Caída en vertical              NaN            4
# 3409                 Caída en vertical             Leve            4
# 3490                  Caída de piedras            Grave            0
# 3491                  Caída de piedras            Grave            0
# 3534                 Caída en vertical             Leve            0
# 3535                 Caída en vertical             Leve            0
# 3769       Deslizamiento por pendiente              NaN            0
# 3770       Deslizamiento por pendiente             Leve            0
#
#       NResponsables  Entrenamiento  ActividadPersonal  ActividadOrganizada  \
# 87                1          False               True                False
# 88                1          False               True                False
# 317               1          False               True                False
# 318               1          False               True                False
# 380               1          False               True                False
# 381               1          False               True                False
# 1018              1          False               True                False
# 1019              1          False               True                False
# 1621              0          False               True                False
# 1622              0          False               True                False
# 2214              2          False              False                 True
# 2215              2          False              False                 True
# 2218              0          False               True                False
# 2219              0          False               True                False
# 2328              1          False              False                 True
# 2329              1          False               True                False
# 2455              1           True              False                False
# 2456              1           True              False                False
# 2826              1           True              False                False
# 2827              1           True              False                False
# 3133              1          False              False                 True
# 3134              1          False              False                 True
# 3265              0           True              False                False
# 3266              1           True              False                False
# 3276              0           True              False                False
# 3277              1           True              False                False
# 3307              2          False               True                False
# 3308              2          False               True                False
# 3408              2          False               True                False
# 3409              2          False               True                False
# 3490              0          False               True                False
# 3491              0          False               True                False
# 3534              0           True              False                False
# 3535              0           True              False                False
# 3769              0           True               True                False
# 3770              0           True               True                False
#
#       Festivo sheet
# 87      False  2020
# 88      False  2020
# 317     False  2020
# 318     False  2020
# 380     False  2020
# 381     False  2020
# 1018    False  2021
# 1019    False  2021
# 1621     True  2022
# 1622    False  2022
# 2214    False  2023
# 2215    False  2023
# 2218    False  2023
# 2219    False  2023
# 2328    False  2023
# 2329    False  2023
# 2455    False  2023
# 2456    False  2023
# 2826    False  2024
# 2827    False  2024
# 3133    False  2024
# 3134    False  2024
# 3265    False  2024
# 3266    False  2024
# 3276    False  2024
# 3277    False  2024
# 3307    False  2024
# 3308    False  2024
# 3408    False  2024
# 3409    False  2024
# 3490    False  2025
# 3491    False  2025
# 3534    False  2025
# 3535    False  2025
# 3769    False  2025
# 3770    False  2025

# %%
dups[["NIF", "FechaParteAccidente", "sheet"]].sort_values(
    ["NIF", "FechaParteAccidente"]
) # Muestra los registros duplicados por hoja - doble comprobación de que son iguales
# Out:
#             NIF FechaParteAccidente sheet
# 3276  02282680E 2024-09-27 21:00:00  2024
# 3277  02282680E 2024-09-27 21:00:00  2024
# 2826  02302403B 2024-01-18 20:15:00  2024
# 2827  02302403B 2024-01-18 20:15:00  2024
# 3133  02442123Y 2024-06-25 16:00:00  2024
# 3134  02442123Y 2024-06-25 16:00:00  2024
# 3534  02652024D 2025-03-02 16:00:00  2025
# 3535  02652024D 2025-03-02 16:00:00  2025
# 2328  02665694V 2023-04-11 00:00:00  2023
# 2329  02665694V 2023-04-11 00:00:00  2023
# 317   04191894Y 2020-08-15 12:00:00  2020
# 318   04191894Y 2020-08-15 12:00:00  2020
# 87    05345381C 2020-02-18 14:00:00  2020
# 88    05345381C 2020-02-18 14:00:00  2020
# 3307  06026687C 2024-10-12 10:30:00  2024
# 3308  06026687C 2024-10-12 10:30:00  2024
# 3769  06574261X 2025-08-01 10:00:00  2025
# 3770  06574261X 2025-08-01 10:00:00  2025
# 1018  06988343T 2021-07-06 15:00:00  2021
# 1019  06988343T 2021-07-06 15:00:00  2021
# 3490  11843025A 2025-02-08 00:00:00  2025
# 3491  11843025A 2025-02-08 00:00:00  2025
# 2218  15941884D 2023-02-22 16:00:00  2023
# 2219  15941884D 2023-02-22 16:00:00  2023
# 3265  50451124A 2024-09-21 09:00:00  2024
# 3266  50451124A 2024-09-21 09:00:00  2024
# 2455  50636271T 2023-06-14 20:30:00  2023
# 2456  50636271T 2023-06-14 20:30:00  2023
# 2214  50676554X 2023-02-20 12:00:00  2023
# 2215  50676554X 2023-02-20 12:00:00  2023
# 1621  50688629X 2022-04-24 10:00:00  2022
# 1622  50688629X 2022-04-24 10:00:00  2022
# 380   51888566Z 2020-09-22 12:00:00  2020
# 381   51888566Z 2020-09-22 12:00:00  2020
# 3408  60249595Z 2024-12-15 00:00:00  2024
# 3409  60249595Z 2024-12-15 00:00:00  2024

# %%
df = df.drop_duplicates(
    subset=[
        "NIF",
        "FechaParteAccidente",
        "sheet"
    ]
) # Elimino los registros duplicados, manteniendo solo uno de ellos (el original)

# %%
df.duplicated(
    subset=[
        "NIF",
        "FechaParteAccidente",
        "sheet"
    ]
).sum() # Verificación de que ya no hay registros duplicados en el DataFrame final
# Out:
# np.int64(0)

# %%
df["NIF"] = df["NIF"].astype(str).str.strip().str.upper() # Normalizo el formato de los NIF para evitar problemas de merge

# %%
df["NIF"].isna().sum(), (df["NIF"]=="").sum() # Todos los NIF están completos, no hay valores nulos ni vacíos!
# Out:
# (np.int64(0), np.int64(0))

# %%
df["FechaParteAccidente"].isna().sum()
# Out:
# np.int64(0)
